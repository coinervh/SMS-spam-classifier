# %%
import numpy as np 
import pandas as pd 

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.preprocessing import MinMaxScaler

from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import GradientBoostingClassifier

from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

import wordcloud

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
#print Classification Report and Accuracy

# %%
def print_validation_report(y_true, y_pred):
    print("Classification Report")
    print(classification_report(y_true, y_pred))
    acc_sc = accuracy_score(y_true, y_pred)
    print("Accuracy : "+ str(acc_sc))
    
    return acc_sc

# %%
# plot confusion matrix
def plot_confusion_matrix(y_true, y_pred):
    mtx = confusion_matrix(y_true, y_pred)
    #fig, ax = plt.subplots(figsize=(4,4))
    sns.heatmap(mtx, annot=True, fmt='d', linewidths=.5,  
                cmap="Blues", cbar=False, ax=ax)
    #  square=True,
    plt.ylabel('true label')
    plt.xlabel('predicted label')

# %%
# part 1 EDA

# %%
data = pd.read_excel(r"C:\Users\user3\AppData\Local\Temp\Temp1_Spam Data.zip\spam.xlsx")
data.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
data = data.drop(["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"], axis=1)
data = data.rename(columns={"v1":"label", "v2":"text"})

# %%
data.describe()
# Out:
#        label                    text
# count   5572                    5572
# unique     2                    5169
# top      ham  Sorry, I'll call later
# freq    4825                      30

# %%
data.groupby("label").describe()
# Out:
#        text
#       count unique                                                top freq
# label
# ham    4825   4516                             Sorry, I'll call later   30
# spam    747    653  Please call our customer service representativ...    4

# %%
#The dataset contains 4825 ham and 747 spam messages.
#or both classes, some messages appear more than once (common phrases, etc.).

# %%
data.label.value_counts()
# Out:
# ham     4825
# spam     747
# Name: label, dtype: int64

# %%
data.label.value_counts().plot.bar();

# %%
#Add numerical label for spam¶
#Target must be numerical for ML classification models

# %%
data['spam'] = data['label'].map( {'spam': 1, 'ham': 0} ).astype(int)
data.head(15)
# Out:
#    label                                               text  spam
# 0    ham  Go until jurong point, crazy.. Available only ...     0
# 1    ham                      Ok lar... Joking wif u oni...     0
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...     1
# 3    ham  U dun say so early hor... U c already then say...     0
# 4    ham  Nah I don't think he goes to usf, he lives aro...     0
# 5   spam  FreeMsg Hey there darling it's been 3 week's n...     1
# 6    ham  Even my brother is not like to speak with me. ...     0
# 7    ham  As per your request 'Melle Melle (Oru Minnamin...     0
# 8   spam  WINNER!! As a valued network customer you have...     1
# 9   spam  Had your mobile 11 months or more? U R entitle...     1
# 10   ham  I'm gonna be home soon and i don't want to tal...     0
# 11  spam  SIX chances to win CASH! From 100 to 20,000 po...     1
# 12  spam  URGENT! You have won a 1 week FREE membership ...     1
# 13   ham  I've been searching for the right words to tha...     0
# 14   ham                I HAVE A DATE ON SUNDAY WITH WILL!!     0

# %%
#1.2 length of message

# %%
#1.3 WordClouds
data_ham  = data[data['spam'] == 0].copy()
data_spam = data[data['spam'] == 1].copy()

# %%
def show_wordcloud(data_ham, title):
    text = ' '.join(data_ham['text'].astype(str).tolist())
    stopwords = set(wordcloud.STOPWORDS)
    
    fig_wordcloud = wordcloud.WordCloud(stopwords=stopwords,background_color='lightgrey',
                    colormap='viridis', width=800, height=600).generate(text)
    
    plt.figure(figsize=(10,7), frameon=True)
    plt.imshow(fig_wordcloud)  
    plt.axis('off')
    plt.title(title, fontsize=20 )
    plt.show()

# %%
show_wordcloud(data_ham, "Ham messages")

# %%
def show_wordcloud(data_spam_or_ham, title):
    text = ' '.join(data_spam_or_ham['text'].astype(str).tolist())
    stopwords = set(wordcloud.STOPWORDS)
    
    fig_wordcloud = wordcloud.WordCloud(stopwords=stopwords,background_color='lightgrey',
                    colormap='viridis', width=800, height=600).generate(text)
    
    plt.figure(figsize=(10,7), frameon=True)
    plt.imshow(fig_wordcloud)  
    plt.axis('off')
    plt.title(title, fontsize=20 )
    plt.show()

# %%
show_wordcloud(data_ham, "Ham messages")

# %%
show_wordcloud(data_spam, "Spam messages")

# %%
#Preprocessing
#Remove Punctuation and Stopwords

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
#NLnltk
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\user3\anaconda3\lib\site-packages (3.6.5)
# Requirement already satisfied: click in c:\users\user3\anaconda3\lib\site-packages (from nltk) (8.0.3)
# Requirement already satisfied: joblib in c:\users\user3\anaconda3\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\user3\anaconda3\lib\site-packages (from nltk) (2021.8.3)
# Requirement already satisfied: tqdm in c:\users\user3\anaconda3\lib\site-packages (from nltk) (4.62.3)
# Requirement already satisfied: colorama in c:\users\user3\anaconda3\lib\site-packages (from click->nltk) (0.4.4)

# %%
import nltk
nltk.download("stopwords")
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [WinError 10060] A
# [nltk_data]     connection attempt failed because the connected party
# [nltk_data]     did not properly respond after a period of time, or
# [nltk_data]     established connection failed because connected host
# [nltk_data]     has failed to respond>
# False

# %%
import nltk
#nltk.download("punkt")
import warnings
warnings.filterwarnings('ignore')

# %%
ham_words = ''
spam_words = ''

# %%
for val in data[data['label'] == 'spam'].text:
    text = val.lower()
    tokens = nltk.word_tokenize(text)
    for words in tokens:
        spam_words = spam_words + words + ' '
        
for val in data[data['label'] == 'ham'].text:
    text = val.lower()
    tokens = nltk.word_tokenize(text)
    for words in tokens:
        ham_words = ham_words + words + ' '

# %%
#NAVIES BAYERS CLASSIFIER
